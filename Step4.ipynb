# %%
import numpy as np
import sympy as sp

# %%
from sympy import init_printing
init_printing(use_latex = True)

# %%
x, nu, t = sp.symbols('x nu t')
phi = (sp.exp(-(x - 4 * t) ** 2 / (4 * nu * (t + 1))) + \
    sp.exp(-(x - 4 * t - 2 * sp.pi) ** 2 / (4 * nu * (t +1))))
phi
# Out:
#                   2                2
#  -(-4⋅t + x - 2⋅π)      -(-4⋅t + x)
#  ───────────────────    ─────────────
#      4⋅ν⋅(t + 1)         4⋅ν⋅(t + 1)
# ℯ                    + ℯ

# %%
phiprime = phi.diff(x)
phiprime
# Out:
#                            2                                         2
#                 -(-4⋅t + x)                         -(-4⋅t + x - 2⋅π)
#                 ─────────────                       ───────────────────
#                  4⋅ν⋅(t + 1)                            4⋅ν⋅(t + 1)
#   (-8⋅t + 2⋅x)⋅ℯ                (-8⋅t + 2⋅x - 4⋅π)⋅ℯ
# - ─────────────────────────── - ───────────────────────────────────────
#           4⋅ν⋅(t + 1)                         4⋅ν⋅(t + 1)

# %%
print(phiprime)
# Out:
# (8*t - 2*x)*exp(-(-4*t + x)**2)/(4*nu*(t + 1)) - (-8*t + 2*x - 4*pi)*exp(-(-4*t + x - 2*pi)**2/(4*nu*(t + 1)))/(4*nu*(t + 1))

# %%
from sympy.utilities.lambdify import lambdify

u = -2 * nu * (phiprime / phi) + 4
print(u)
# Out:
# -2*nu*(-(-8*t + 2*x)*exp(-(-4*t + x)**2/(4*nu*(t + 1)))/(4*nu*(t + 1)) - (-8*t + 2*x - 4*pi)*exp(-(-4*t + x - 2*pi)**2/(4*nu*(t + 1)))/(4*nu*(t + 1)))/(exp(-(-4*t + x - 2*pi)**2/(4*nu*(t + 1))) + exp(-(-4*t + x)**2/(4*nu*(t + 1)))) + 4

# %%
ufunc = lambdify((t, x, nu), u)
print(ufunc(1, 4, 3))
# Out:
# 3.49170664206445

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

nx = 101
nt = 100
dx = 2 * np.pi / (nx - 1)
nu = .07
dt = dx * nu

x = np.linspace(0, 2 * np.pi, nx)
un = np.empty(nx)
t = 0

u = np.asarray([ufunc(t, x0, nu) for x0 in x])
u
# Out:
# array([4.        , 4.06283185, 4.12566371, 4.18849556, 4.25132741,
#        4.31415927, 4.37699112, 4.43982297, 4.50265482, 4.56548668,
#        4.62831853, 4.69115038, 4.75398224, 4.81681409, 4.87964594,
#        4.9424778 , 5.00530965, 5.0681415 , 5.13097336, 5.19380521,
#        5.25663706, 5.31946891, 5.38230077, 5.44513262, 5.50796447,
#        5.57079633, 5.63362818, 5.69646003, 5.75929189, 5.82212374,
#        5.88495559, 5.94778745, 6.0106193 , 6.07345115, 6.136283  ,
#        6.19911486, 6.26194671, 6.32477856, 6.38761042, 6.45044227,
#        6.51327412, 6.57610598, 6.63893783, 6.70176967, 6.76460125,
#        6.82742866, 6.89018589, 6.95176632, 6.99367964, 6.72527549,
#        4.        , 1.27472451, 1.00632036, 1.04823368, 1.10981411,
#        1.17257134, 1.23539875, 1.29823033, 1.36106217, 1.42389402,
#        1.48672588, 1.54955773, 1.61238958, 1.67522144, 1.73805329,
#        1.80088514, 1.863717  , 1.92654885, 1.9893807 , 2.05221255,
#        2.11504441, 2.17787626, 2.24070811, 2.30353997, 2.36637182,
#        2.42920367, 2.49203553, 2.55486738, 2.61769923, 2.68053109,
#        2.74336294, 2.80619479, 2.86902664, 2.9318585 , 2.99469035,
#        3.0575222 , 3.12035406, 3.18318591, 3.24601776, 3.30884962,
#        3.37168147, 3.43451332, 3.49734518, 3.56017703, 3.62300888,
#        3.68584073, 3.74867259, 3.81150444, 3.87433629, 3.93716815,
#        4.        ])

# %%
plt.figure(figsize=(11,7), dpi=100)
plt.plot(x, u, marker='o', lw=2)
plt.xlim([0, 2 * np.pi])
plt.ylim([0, 10]);

# %%
for n in range(nt):
    un = u.copy()
    for i in range(1, nx-1):
        u[i] = un[i] - un[i] * dt / dx * (un[i] - un[i-1]) + nu * dt / dx **2 + (un[i+1] -2 * un[i] + un[i-1])
    u[0] = un[0] - un[0] * dt / dx * (un[0] - un[-2]) + nu * dt / dx**2 * (un[1] - 2 * un[0] + un[-2])
    u[-1] = u[0]

u_analytical = np.asarray([ufunc(nt * dt, xi, nu) for xi in x])
# Out:
# C:\Users\Hye-lee\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Hye-lee\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# C:\Users\Hye-lee\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in double_scalars
#   """
# C:\Users\Hye-lee\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """

# %%
plt.figure(figsize=(11, 7), dpi=100)
plt.plot(x,u, marker='o', lw=2, label='Computational')
plt.plot(x, u_analytical, label='Analytical')
plt.xlim([0, 2 * np.pi])
plt.ylim([0, 10])
plt.legend();
